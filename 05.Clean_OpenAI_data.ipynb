# %%
import pandas as pd
import re
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import logging

# ========================
# CONFIG
# ========================

INPUT_CSV = "Data_clean/08.researchers_with_themes_expertise_openai.csv"
OUTPUT_CSV = "Data_clean/08.researchers_with_themes_expertise_cleaned.csv"

SIMILARITY_THRESHOLD = 85  # Fuzzy matching similarity threshold

# Set up logging
logging.basicConfig(level=logging.INFO)

# ========================
# DICTIONARIES
# (Now all keys/values are lowercase for consistent handling)
# ========================

SYNONYMS = {
    # Machine Learning
    "ml-based research": "machine learning",
    "machine learning algorithms": "machine learning",
    "large language models": "machine learning",
    "llms": "machine learning",
    "ml research": "machine learning",
    "machine-learning": "machine learning",

    # Neuroimaging
    "fnirs neuroimaging": "fnirs",
    "functional near-infrared spectroscopy (fnirs)": "fnirs",
    "functional near-infrared spectroscopy": "fnirs",
    "electroencephalography": "eeg",
    "fmri": "fmri",
    "functional magnetic resonance imaging": "fmri",
    "optical imaging": "neuroimaging",
    "imaging techniques": "neuroimaging",
    "cortical imaging": "neuroimaging",

    # Cross-linguistic
    "crosslinguistic evidence": "cross-linguistic evidence",
    "cross-linguistic comparison": "cross-linguistic comparison",
    "cross-linguistic research": "cross-linguistic research",

    # Eye Tracking
    "eye-tracking": "eye tracking",
    "eye tracking": "eye tracking",

    # Multimodal Communication
    "multimodal communication research": "multimodal communication",
    "multimodal research": "multimodal communication",

    # Bayesian
    "bayesian analyses": "bayesian analysis",
    "bayesian approach": "bayesian analysis",
    "bayesian inference": "bayesian analysis",
    "bayesian models": "bayesian analysis",

    # Deaf/Sign Language
    "sign languages": "sign language",
    "sign language": "sign language",
    "ngt": "sign language",
    "deaf community": "deaf communities",

    # Cochlear Implant
    "cochlear implantation": "cochlear implant",

    # GPT / ChatGPT
    "chatgpt": "chatgpt",
    "gpt": "chatgpt",

    # Variation of lexical usage
    "lexicography": "lexicography",
    "computational methods": "computational methods",
    "computational modeling": "computational modeling",

    # Random Forest
    "random forest models": "random forest",
    "random forest model": "random forest",

    # Observational Methods
    "observational study designs": "observational methods",

    # Emotional processes
    "emotional processes": "emotional processing",

    # DGS-LEX
    "dgs-lex": "dgs-lex",

    # DFG-Funded
    "dfg-funded research training group": "dfg-funded research training group",

    # PhD
    "phd thesis": "phd thesis",

    # Non-linguistic
    "non-linguistic deceptions": "nonlinguistic deceptions",
    "qud": "qud",
    "elan": "elan",
    "openpose": "openpose",
}

ACRONYMS = {
    "fmir": "fmri",
    "ml": "machine learning",
    "fmri": "fmri",
    "fnirs": "fnirs",
    "eeg": "eeg",
    "erps": "erps",
    "dgs-lex": "dgs-lex",
    "tms": "tms",
    "ai": "ai",
    "cnn": "convolutional neural networks",
    "rnn": "recurrent neural networks",
    "dfg-funded research training group": "dfg-funded research training group"
}

REMOVE_TERMS = {
    "language", "education", "philosophy",
    "psychology", "communication", "research methodology", "ai innovation",
    "information structure", "logic", "discourse analysis", "research focus",
    "studies", "areas of expertise", "experimental approach", "experimental investigations",
    "data analysis", "methodological frameworks", "research methodologies", "teaching",
    "translation", "programming", "therapy", "experimental methodologies", "ai innovation",
    "linguistics", "phd", "structure", "metaphor", "research contributions", "research opportunities", "research outcomes"

}

# ========================
# HELPER FUNCTIONS
# ========================

def normalize_keyword(kw: str) -> str:
    """
    1) Convert the keyword to lowercase, strip whitespace.
    """
    return kw.strip().lower()

def map_synonym(kw: str) -> str:
    """
    2) If the entire lowercase keyword is in SYNONYMS, replace it.
       Log the mapping if it happens.
    """
    if kw in SYNONYMS:
        mapped_value = SYNONYMS[kw]
        logging.info(f"[Synonym mapped] '{kw}' -> '{mapped_value}'")
        return mapped_value
    return kw

def enforce_acronyms(final_label: str) -> str:
    """
    3) If final_label is in ACRONYMS, replace it.
       Log the enforcement if it happens.
    """
    if final_label in ACRONYMS:
        new_label = ACRONYMS[final_label]
        logging.info(f"[Acronym enforced] '{final_label}' -> '{new_label}'")
        return new_label
    return final_label

def merge_similar_keywords(keywords, threshold=SIMILARITY_THRESHOLD):
    """
    4) Merge fuzzy-similar keywords.
       If similarity >= threshold, skip adding duplicates.
       Log whenever we skip a near-duplicate.
    """
    merged = []
    for kw in keywords:
        matched = False
        for existing in merged:
            ratio = fuzz.ratio(kw.lower(), existing.lower())
            if ratio >= threshold:
                logging.info(f"[Fuzzy merge] Skipped '{kw}' ~ '{existing}' (ratio={ratio})")
                matched = True
                break
        if not matched:
            merged.append(kw)
    return merged

def clean_themes_or_expertise(cell_value: str) -> str:
    """
    5) Clean and normalize a 'Themes' or 'Expertise' cell.
       - Split on multiple delimiters (; and ,).
       - Lowercase each keyword.
       - Map synonyms.
       - Enforce acronyms.
       - Use fuzzy dedup to merge near-duplicates.
       - Remove vague/forbidden terms.
       - Sort the final keywords alphabetically.
       - Log if we remove a term from REMOVE_TERMS.
    """
    if not isinstance(cell_value, str):
        return ""

    # ---- 1) Split on semicolon OR comma (add more if needed) ----
    #    We’ll split on either delimiter and accumulate tokens
    tokens_raw = re.split(r'[;,]', cell_value)  
    #   This returns all substrings split by either semicolon or comma
    items = [x.strip() for x in tokens_raw if x.strip()]

    # ---- 2) Normalize (lowercase, synonyms, acronyms) ----
    cleaned = []
    for it in items:
        it_norm = normalize_keyword(it)
        if not it_norm:
            continue
        
        # Synonyms
        mapped = map_synonym(it_norm)
        
        # Acronyms
        mapped_acr = enforce_acronyms(mapped)
        
        cleaned.append(mapped_acr)

    # ---- 3) Fuzzy duplicates and remove exact duplicates within the list ----
    # First, remove exact duplicates
    unique_cleaned = []
    for kw in cleaned:
        if kw not in unique_cleaned:
            unique_cleaned.append(kw)
        else:
            logging.info(f"[Exact duplicate removed] '{kw}'")

    # Then, fuzzy merge
    deduped = merge_similar_keywords(unique_cleaned, SIMILARITY_THRESHOLD)

    # ---- 4) Remove terms in REMOVE_TERMS ----
    final_filtered = []
    for term in deduped:
        if term.lower() in REMOVE_TERMS:
            logging.info(f"[Removed Term] '{term}' (in REMOVE_TERMS)")
        else:
            final_filtered.append(term)

    # ---- 5) Sort final keywords alphabetically for consistency ----
    final_filtered.sort()

    # ---- 6) Return them as a semicolon-separated string ----
    return "; ".join(final_filtered)

# ========================
# MAIN FUNCTION
# ========================
def main():
    df = pd.read_csv(INPUT_CSV)
    
    # Drop duplicates by 'Full Name'
    before_dedup = df.shape[0]
    df.drop_duplicates(subset="Full Name", keep="first", inplace=True)
    after_dedup = df.shape[0]
    logging.info(f"Removed {before_dedup - after_dedup} duplicate row(s) based on Full Name.")

    # Clean the Themes and Expertise columns
    df["Themes_Clean"] = df["Themes"].apply(clean_themes_or_expertise)
    df["Expertise_Clean"] = df["Expertise"].apply(clean_themes_or_expertise)
    
    # Save the cleaned dataframe
    df.to_csv(OUTPUT_CSV, index=False)
    logging.info(f"Saved cleaned file to '{OUTPUT_CSV}'.")

if __name__ == "__main__":
    main()
# Out:
# INFO:root:Removed 0 duplicate row(s) based on Full Name.
# INFO:root:[Synonym mapped] 'lexicography' -> 'lexicography'
# INFO:root:[Exact duplicate removed] 'digital scenes generation'
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Removed Term] 'ai innovation' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Removed Term] 'linguistics' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'ai innovation' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'sign language' -> 'sign language'
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Synonym mapped] 'openpose' -> 'openpose'
# INFO:root:[Exact duplicate removed] 'research projects'
# INFO:root:[Exact duplicate removed] 'sign language'
# INFO:root:[Fuzzy merge] Skipped 'sign language' ~ 'signed languages' (ratio=90)
# INFO:root:[Removed Term] 'therapy' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'cochlear implantation' -> 'cochlear implant'
# INFO:root:[Synonym mapped] 'deaf community' -> 'deaf communities'
# INFO:root:[Exact duplicate removed] 'cochlear implant'
# INFO:root:[Exact duplicate removed] 'music perception'
# INFO:root:[Fuzzy merge] Skipped 'verbal communication' ~ 'nonverbal communication' (ratio=93)
# INFO:root:[Removed Term] 'research outcomes' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'animal communication' ~ 'animal vocal communication' (ratio=87)
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Removed Term] 'research methodologies' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'ai innovation' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'attentional orientation' ~ 'attention orienting' (ratio=86)
# INFO:root:[Removed Term] 'metaphor' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'computational methods' -> 'computational methods'
# INFO:root:[Removed Term] 'logic' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'philosophy' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'education' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'linguistic cognition' ~ 'linguistic communication' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'linguistic production' ~ 'linguistic perception' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'linguistic interpretation' ~ 'linguistic interaction' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'research applications' ~ 'research implications' (ratio=90)
# INFO:root:[Removed Term] 'research methodologies' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research opportunities' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research outcomes' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research contributions' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'neural network theories' ~ 'neural network themes' (ratio=91)
# INFO:root:[Fuzzy merge] Skipped 'neural network data analysis' ~ 'neural network social analysis' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'neural network social research' ~ 'neural network social science' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'neural network cognitive methods' ~ 'neural network cognitive evolution' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'neural network cognitive structure' ~ 'neural network cognitive science' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'neural network evolution' ~ 'neural network social evolution' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'neural network cognitive research' ~ 'neural network cognitive science' (ratio=86)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'dfg-funded research training group' -> 'dfg-funded research training group'
# INFO:root:[Acronym enforced] 'dfg-funded research training group' -> 'dfg-funded research training group'
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'lexical sense integration' ~ 'lexical sense interpolation' (ratio=92)
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Synonym mapped] 'sign language' -> 'sign language'
# INFO:root:[Fuzzy merge] Skipped 'extensional constructions' ~ 'intensional constructions' (ratio=92)
# INFO:root:[Synonym mapped] 'computational modeling' -> 'computational modeling'
# INFO:root:[Fuzzy merge] Skipped 'syntactic information' ~ 'syntactic integration' (ratio=86)
# INFO:root:[Synonym mapped] 'cross-linguistic research' -> 'cross-linguistic research'
# INFO:root:[Synonym mapped] 'functional magnetic resonance imaging' -> 'fmri'
# INFO:root:[Acronym enforced] 'fmri' -> 'fmri'
# INFO:root:[Fuzzy merge] Skipped 'cross-linguistic research' ~ 'linguistic research' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'cognitive neuroscience' ~ 'cognitive science' (ratio=87)
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'lexicography' -> 'lexicography'
# INFO:root:[Removed Term] 'ai innovation' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Removed Term] 'philosophy' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'linguistics' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'linguistics' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'linguistic research' ~ 'psycholinguistic research' (ratio=86)
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'psychology' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'gesture and cognition' ~ 'gesture and neurocognition' (ratio=89)
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Fuzzy merge] Skipped 'research implications' ~ 'research applications' (ratio=90)
# INFO:root:[Removed Term] 'research contributions' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research outcomes' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research opportunities' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'translation' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'cross-linguistic comparison' -> 'cross-linguistic comparison'
# INFO:root:[Synonym mapped] 'sign languages' -> 'sign language'
# INFO:root:[Fuzzy merge] Skipped 'silent gesture communication' ~ 'gesture communication' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'communication systems' ~ 'novel communication systems' (ratio=88)
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'language' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'multimodal communication research' -> 'multimodal communication'
# INFO:root:[Synonym mapped] 'cross-linguistic comparison' -> 'cross-linguistic comparison'
# INFO:root:[Removed Term] 'communication' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'random forest models' -> 'random forest'
# INFO:root:[Synonym mapped] 'machine learning algorithms' -> 'machine learning'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'bayesian analyses' -> 'bayesian analysis'
# INFO:root:[Exact duplicate removed] 'random forest'
# INFO:root:[Exact duplicate removed] 'cross-validation method'
# INFO:root:[Fuzzy merge] Skipped 'linear mixed-effect models' ~ 'linear mixed-effects models' (ratio=98)
# INFO:root:[Exact duplicate removed] 'vr-based text-to-3d scene system'
# INFO:root:[Exact duplicate removed] 'word embeddings'
# INFO:root:[Fuzzy merge] Skipped 'neural named entity recognition' ~ 'named entity recognition' (ratio=87)
# INFO:root:[Synonym mapped] 'large language models' -> 'machine learning'
# INFO:root:[Synonym mapped] 'openpose' -> 'openpose'
# INFO:root:[Synonym mapped] 'chatgpt' -> 'chatgpt'
# INFO:root:[Exact duplicate removed] 'machine learning'
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'dfg research project' ~ 'research projects' (ratio=86)
# INFO:root:[Removed Term] 'linguistics' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'metaphor' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'lexicography' -> 'lexicography'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Exact duplicate removed] 'linear mixed-effects models'
# INFO:root:[Fuzzy merge] Skipped 'non-manual constructions' ~ 'manual constructions' (ratio=91)
# INFO:root:[Fuzzy merge] Skipped 'production experiments' ~ 'perception experiments' (ratio=86)
# INFO:root:[Synonym mapped] 'elan' -> 'elan'
# INFO:root:[Fuzzy merge] Skipped 'cognitive assessment outcomes' ~ 'cognitive assessment practices' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'cognitive assessment scales' ~ 'cognitive assessment tools' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'social assessment procedures' ~ 'social assessment measures' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'cognitive assessment methods' ~ 'cognitive assessment tools' (ratio=89)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'optical imaging' -> 'neuroimaging'
# INFO:root:[Acronym enforced] 'fnirs' -> 'fnirs'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Acronym enforced] 'fnirs' -> 'fnirs'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Exact duplicate removed] 'mri'
# INFO:root:[Exact duplicate removed] 'fnirs'
# INFO:root:[Exact duplicate removed] 'eeg'
# INFO:root:[Exact duplicate removed] 'spectroscopy techniques'
# INFO:root:[Exact duplicate removed] 'bayesian stats'
# INFO:root:[Exact duplicate removed] 'cross-modal activation'
# INFO:root:[Fuzzy merge] Skipped 'linear relationship' ~ 'non-linear relationship' (ratio=90)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'expertise in research methods' ~ 'expertise in research outcomes' (ratio=85)
# INFO:root:[Exact duplicate removed] 'forward translation'
# INFO:root:[Exact duplicate removed] 'high-resolution imaging'
# INFO:root:[Exact duplicate removed] 'voxel-based analysis'
# INFO:root:[Exact duplicate removed] 'linear mixed-effects models'
# INFO:root:[Exact duplicate removed] 'forward translation'
# INFO:root:[Exact duplicate removed] 'resting-state fmri'
# INFO:root:[Exact duplicate removed] 'high-resolution imaging'
# INFO:root:[Exact duplicate removed] 'voxel-based analysis'
# INFO:root:[Exact duplicate removed] 'linear mixed-effects models'
# INFO:root:[Exact duplicate removed] 'forward translation'
# INFO:root:[Exact duplicate removed] 'resting-state fmri'
# INFO:root:[Exact duplicate removed] 'high-resolution imaging'
# INFO:root:[Exact duplicate removed] 'voxel-based analysis'
# INFO:root:[Exact duplicate removed] 'linear mixed-effects models'
# INFO:root:[Exact duplicate removed] 'forward translation'
# INFO:root:[Exact duplicate removed] 'resting-state fmri'
# INFO:root:[Exact duplicate removed] 'high-resolution imaging'
# INFO:root:[Exact duplicate removed] 'voxel-based analysis'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'conventional implicatures' ~ 'conversational implicatures' (ratio=92)
# INFO:root:[Fuzzy merge] Skipped 'acceptability judgment experiment design' ~ 'acceptability judgment experiment' (ratio=90)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'research experience' ~ 'research expertise' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'research publications' ~ 'research implications' (ratio=90)
# INFO:root:[Fuzzy merge] Skipped 'research applications' ~ 'research implications' (ratio=90)
# INFO:root:[Removed Term] 'research focus' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research methodologies' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research outcomes' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'research contributions' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'functional magnetic resonance imaging' -> 'fmri'
# INFO:root:[Acronym enforced] 'fmri' -> 'fmri'
# INFO:root:[Synonym mapped] 'electroencephalography' -> 'eeg'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Exact duplicate removed] 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'neurological investigations' ~ 'neurobiological investigations' (ratio=95)
# INFO:root:[Fuzzy merge] Skipped 'experimental task' ~ 'experimental trials' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'experimental tasks' ~ 'experimental trials' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'experimental tools' ~ 'experimental trials' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'experimental models' ~ 'experimental methods' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'experimental approaches' ~ 'experimental approach' (ratio=95)
# INFO:root:[Removed Term] 'experimental approach' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Exact duplicate removed] 'neurobiology of language'
# INFO:root:[Exact duplicate removed] 'metonymy'
# INFO:root:[Exact duplicate removed] 'late positivity'
# INFO:root:[Fuzzy merge] Skipped 'event-related potentials (erps)' ~ 'event-related potential (erp)' (ratio=97)
# INFO:root:[Fuzzy merge] Skipped 'attentional orientation' ~ 'attention orienting' (ratio=86)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'computational methods' -> 'computational methods'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'methodological frameworks' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'phd' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'sign language' -> 'sign language'
# INFO:root:[Synonym mapped] 'crosslinguistic evidence' -> 'cross-linguistic evidence'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'experimental approach' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'bayesian stats' ~ 'bayesian statistics' (ratio=85)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'bayesian models' -> 'bayesian analysis'
# INFO:root:[Exact duplicate removed] 'mri'
# INFO:root:[Exact duplicate removed] 'data analysis'
# INFO:root:[Exact duplicate removed] 'bayesian analysis'
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'observational study designs' -> 'observational methods'
# INFO:root:[Synonym mapped] 'computational modeling' -> 'computational modeling'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'cross-linguistic comparison' -> 'cross-linguistic comparison'
# INFO:root:[Fuzzy merge] Skipped 'manual signs' ~ 'nonmanual signs' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'nonmanual features' ~ 'nonmanual gestures' (ratio=89)
# INFO:root:[Synonym mapped] 'eye tracking' -> 'eye tracking'
# INFO:root:[Synonym mapped] 'cross-linguistic comparison' -> 'cross-linguistic comparison'
# INFO:root:[Exact duplicate removed] 'linear mixed-effects models'
# INFO:root:[Exact duplicate removed] 'false implicatures'
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'lexicography' -> 'lexicography'
# INFO:root:[Fuzzy merge] Skipped 'lexical sense template' ~ 'lexical sense plan' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'lexical sense pattern' ~ 'lexical sense plan' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'lexical sense tree' ~ 'lexical sense transfer' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'lexical sense table' ~ 'lexical sense tool' (ratio=86)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'experimental approach' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'functional magnetic resonance imaging' -> 'fmri'
# INFO:root:[Acronym enforced] 'fmri' -> 'fmri'
# INFO:root:[Fuzzy merge] Skipped 'mri' ~ 'fmri' (ratio=86)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'eye-tracking' -> 'eye tracking'
# INFO:root:[Synonym mapped] 'functional near-infrared spectroscopy' -> 'fnirs'
# INFO:root:[Acronym enforced] 'fnirs' -> 'fnirs'
# INFO:root:[Synonym mapped] 'random forest models' -> 'random forest'
# INFO:root:[Removed Term] 'ai innovation' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'electroencephalography' -> 'eeg'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'programming' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'iconicity rating' ~ 'iconicity ratings' (ratio=97)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Removed Term] 'discourse analysis' (in REMOVE_TERMS)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'functional magnetic resonance imaging' -> 'fmri'
# INFO:root:[Acronym enforced] 'fmri' -> 'fmri'
# INFO:root:[Synonym mapped] 'openpose' -> 'openpose'
# INFO:root:[Synonym mapped] 'computational modeling' -> 'computational modeling'
# INFO:root:[Fuzzy merge] Skipped 'fmri' ~ 'mri' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'information structure' (in REMOVE_TERMS)
# INFO:root:[Fuzzy merge] Skipped 'eeg experiments' ~ 'erp experiments' (ratio=87)
# INFO:root:[Synonym mapped] 'computational methods' -> 'computational methods'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Exact duplicate removed] 'research assistant expertise'
# INFO:root:[Removed Term] 'experimental approach' (in REMOVE_TERMS)
# INFO:root:[Synonym mapped] 'ml-based research' -> 'machine learning'
# INFO:root:[Synonym mapped] 'large language models' -> 'machine learning'
# INFO:root:[Synonym mapped] 'chatgpt' -> 'chatgpt'
# INFO:root:[Exact duplicate removed] 'machine learning'
# INFO:root:[Exact duplicate removed] 'machine learning'
# INFO:root:[Synonym mapped] 'fmri' -> 'fmri'
# INFO:root:[Acronym enforced] 'fmri' -> 'fmri'
# INFO:root:[Synonym mapped] 'eye tracking' -> 'eye tracking'
# INFO:root:[Fuzzy merge] Skipped 'manual kinematic signatures' ~ 'temporal kinematic signatures' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'level-2 perspective-taking' ~ 'level-1 perspective-taking' (ratio=96)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'computational methods' -> 'computational methods'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'computational methods' -> 'computational methods'
# INFO:root:[Synonym mapped] 'sign language' -> 'sign language'
# INFO:root:[Exact duplicate removed] 'computational methods'
# INFO:root:[Fuzzy merge] Skipped 'verbal input' ~ 'nonverbal input' (ratio=89)
# INFO:root:[Exact duplicate removed] 'gesture and mental imagery'
# INFO:root:[Fuzzy merge] Skipped 'gesture and perception' ~ 'gesture perception' (ratio=90)
# INFO:root:[Fuzzy merge] Skipped 'gesture and cognition' ~ 'gesture recognition' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'gesture and mental representation' ~ 'gesture and spatial representation' (ratio=90)
# INFO:root:[Exact duplicate removed] 'research impact'
# INFO:root:[Fuzzy merge] Skipped 'data validation' ~ 'data evaluation' (ratio=87)
# INFO:root:[Synonym mapped] 'eye tracking' -> 'eye tracking'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'offline learning' ~ 'online learning' (ratio=90)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination disorders learning' ~ 'oral sensorimotor coordination disorders training' (ratio=94)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor integration interventions' ~ 'oral sensorimotor integration training' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor integration assessment' ~ 'oral sensorimotor control assessment' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination models' ~ 'oral sensorimotor adaptation models' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination interventions' ~ 'oral sensorimotor adaptation interventions' (ratio=88)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor learning models' ~ 'oral sensorimotor learning' (ratio=88)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor learning interventions' ~ 'oral sensorimotor adaptation interventions' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor learning studies' ~ 'oral sensorimotor learning' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor learning therapy' ~ 'oral sensorimotor learning' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation deficits' ~ 'oral sensorimotor adaptation models' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation theories' ~ 'oral sensorimotor adaptation interventions' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation research' ~ 'oral sensorimotor adaptation models' (ratio=86)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation training' ~ 'oral sensorimotor integration training' (ratio=88)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation impairments' ~ 'oral sensorimotor adaptation interventions' (ratio=85)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor adaptation rehabilitation' ~ 'oral sensorimotor coordination rehabilitation' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination disorders mechanisms' ~ 'oral sensorimotor coordination disorders training' (ratio=88)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination disorders theories' ~ 'oral sensorimotor coordination disorders training' (ratio=90)
# INFO:root:[Fuzzy merge] Skipped 'oral sensorimotor coordination disorders research' ~ 'oral sensorimotor coordination disorders training' (ratio=88)
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Fuzzy merge] Skipped 'perception experiments' ~ 'production experiments' (ratio=86)
# INFO:root:[Removed Term] 'data analysis' (in REMOVE_TERMS)
# INFO:root:[Removed Term] 'therapy' (in REMOVE_TERMS)
# INFO:root:[Exact duplicate removed] 'data analysis modeling'
# INFO:root:[Fuzzy merge] Skipped 'research software validity' ~ 'research software usability' (ratio=87)
# INFO:root:[Fuzzy merge] Skipped 'research software adaptability' ~ 'research software usability' (ratio=88)
# INFO:root:[Fuzzy merge] Skipped 'research software engineering personnel selection' ~ 'research software engineering personnel' (ratio=89)
# INFO:root:[Fuzzy merge] Skipped 'research software validity measures' ~ 'research software measures' (ratio=85)
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Exact duplicate removed] 'least collaborative effort'
# INFO:root:[Acronym enforced] 'eeg' -> 'eeg'
# INFO:root:[Synonym mapped] 'bayesian analyses' -> 'bayesian analysis'
# INFO:root:Saved cleaned file to 'Data_clean/08.researchers_with_themes_expertise_cleaned.csv'.
