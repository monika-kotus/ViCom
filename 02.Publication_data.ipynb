# %% [markdown]
# # 1. Set Up the OpenAlex API Integration

# %%
pip install requests pandas

# %% [markdown]
# # Step 1: Load and Inspect the Data

# %%
import pandas as pd
# Load researcher data
file_path = "Data_clean/01_participants_with_geo.csv"
researchers = pd.read_csv(file_path)

# Inspect the data
print(researchers.head())
# Out:
#             full_name   first_name last_name tittle  \
# 0      Federica Amici     Federica     Amici    Dr.
# 1   Carly A. Anderson     Carly A.  Anderson    NaN
# 2  Mailin Ines Antomo  Mailin Ines    Antomo    Dr.
# 3         Nadine Bade       Nadine      Bade    Dr.
# 4      Kathryn Barnes      Kathryn    Barnes    NaN
#
#                    Affiliation                                 Email  \
# 0        University of Leipzig                      amici@eva.mpg.de
# 1    University College London              carly.anderson@ucl.ac.uk
# 2      University of Göttingen  mailin.antomo@phil.uni-goettingen.de
# 3        University of Potsdam            nadine.bade@uni-potsdam.de
# 4  Goethe University Frankfurt        barnes@lingua.uni-frankfurt.de
#
#                                                Photo   Latitude  Longitude
# 0  https://i0.wp.com/vicom.info/wp-content/upload...  51.338574  12.378462
# 1  https://i0.wp.com/vicom.info/wp-content/upload...  51.524559  -0.134040
# 2  https://i0.wp.com/vicom.info/wp-content/upload...  51.541495   9.937595
# 3  https://i0.wp.com/vicom.info/wp-content/upload...  52.401031  13.011910
# 4  https://i0.wp.com/vicom.info/wp-content/upload...  50.127068   8.667763

# %% [markdown]
# # Step 3: Search for ALl Researchers in OpenAlex

# %%
import requests
import pandas as pd

# Load researcher data
def load_researcher_data(file_path):
    """Load researchers' data from a CSV file."""
    return pd.read_csv(file_path)

# Search for a researcher in OpenAlex
def search_researcher(name):
    """Search for a researcher by name in OpenAlex."""
    url = "https://api.openalex.org/authors"
    params = {"filter": f"display_name.search:{name}", "per-page": 5}
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("results", [])
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

# Fetch works (publications) for a researcher by author ID
def fetch_publications(author_id, start_year=2018):
    """Fetch works for a researcher by author ID."""
    url = "https://api.openalex.org/works"
    params = {
        "filter": f"author.id:{author_id},from_publication_date:{start_year}-01-01",
        "per-page": 50
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        return response.json().get("results", [])
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []


def fetch_all_publications(author_id, start_year=2018):
    """Fetch all publications for a researcher by author ID, handling pagination."""
    url = "https://api.openalex.org/works"
    publications = []
    page = 1  # Start from the first page

    while True:
        params = {
            "filter": f"author.id:{author_id},from_publication_date:{start_year}-01-01",
            "per-page": 50,  # Maximum allowed per page
            "page": page
        }
        response = requests.get(url, params=params)

        if response.status_code == 200:
            results = response.json().get("results", [])
            publications.extend(results)
            
            # Check if there are more pages
            if "next" in response.json() and response.json()["next"]:
                page += 1
            else:
                break
        else:
            print(f"Error fetching publications: {response.status_code} - {response.text}")
            break

    return publications




# Reconstruct the abstract from OpenAlex's inverted index
def reconstruct_abstract(inverted_index):
    """Reconstruct the abstract from OpenAlex's inverted index."""
    if not inverted_index:
        return "Abstract not available"
    abstract = []
    for word, positions in inverted_index.items():
        for position in positions:
            while len(abstract) <= position:
                abstract.append("")
            abstract[position] = word
    reconstructed = " ".join(abstract)
    return reconstructed.lstrip("Abstract").strip()


# Extract publication source with link
def construct_source_with_openalex_id(publication):
    """Construct a source column with a clickable OpenAlex ID link."""
    # Get the OpenAlex ID from the publication metadata
    openalex_id = publication.get("id")
    
    if openalex_id:
        # Return a clickable OpenAlex link
        return f'<a href="{openalex_id}" target="_blank">OpenAlex</a>'
    else:
        # Fallback if the OpenAlex ID is missing
        return "OpenAlex ID not available"



def extract_primary_topic(publication):
    """Extract the primary topic of a publication."""
    primary_topic = publication.get("primary_topic")
    if primary_topic and isinstance(primary_topic, dict):
        return primary_topic.get("display_name", "Topic not available")
    return "Topic not available"


# Add open access information
def get_open_access_status(publication):
    """Get the open access status of a publication."""
    open_access = publication.get("open_access", {})
    return open_access.get("is_oa", False)


def check_affiliation_match(publication, researcher_affiliation):
    """Check if the affiliation in the publication matches the researcher's affiliation."""
    # Extract institutions from the publication
    publication_institutions = [
        inst.get("display_name", "Unknown")
        for authorship in publication.get("authorships", [])
        for inst in authorship.get("institutions", [])
    ]

    # Check if the researcher's affiliation is listed in the publication institutions
    matched_affiliation = "Yes" if researcher_affiliation in publication_institutions else "No"

    # Define review flag logic
    review_flag = "Yes" if matched_affiliation == "No" or not publication_institutions else "No"

    return ", ".join(publication_institutions), matched_affiliation, review_flag




# Process a single researcher
def process_researcher(row):
    """Process a single researcher to retrieve and validate their publications."""
    full_name = row['full_name']
    first_name, last_name = full_name.split()[0], full_name.split()[-1]
    researcher_affiliation = row['Affiliation']
    print(f"Processing researcher: {full_name} with affiliation: {researcher_affiliation}")

    # Search for researcher in OpenAlex using full name
    matches = search_researcher(full_name)

    # If no matches, search using first and last name only
    if not matches:
        short_name = f"{first_name} {last_name}"
        print(f"No matches found for {full_name}, trying {short_name}")
        matches = search_researcher(short_name)

    # If still no matches, add a placeholder row and return
    if not matches:
        print(f"No matches found for {full_name}")
        return [{
            "Researcher": full_name,
            "Year": None,
            "Type": "No publications found",
            "Title": None,
            "Abstract": None,
            "Source": None,
            "Authors": None,
            "Database Affiliation": researcher_affiliation,
            "Publication Institutions": None,
            "Matched Affiliation": "No",
            "Topic": None,
            "Review Flag": "Yes",  # Flag for manual review
        }]

    # Use the first match
    author_id = matches[0]["id"]
    print(f"Selected match: {matches[0]['display_name']} with ID: {author_id}")

    # Fetch all publications (handles pagination)
    publications = fetch_all_publications(author_id)
    if not publications:
        print(f"No publications found for {full_name}")
        # Add a placeholder row for researchers with no publications
        return [{
            "Researcher": full_name,
            "Year": None,
            "Type": "No publications found",
            "Title": None,
            "Abstract": None,
            "Source": None,
            "Authors": None,
            "Database Affiliation": researcher_affiliation,
            "Publication Institutions": None,
            "Matched Affiliation": "No",
            "Topic": None,
            "Review Flag": "Yes",  # Flag for manual review
        }]

    # Collect valid publications
    valid_publications = []
    for pub in publications:
        # Extract title
        title = pub.get("title", "Title not available")

        # Reconstruct abstract
        abstract = reconstruct_abstract(pub.get("abstract_inverted_index", {}))

        # Construct source with OpenAlex link
        source = construct_source_with_openalex_id(pub)

        # Check for affiliation match and flag if needed
        publication_institutions, matched_affiliation, review_flag = check_affiliation_match(pub, researcher_affiliation)

        # Extract topics
        topics = extract_primary_topic(pub)

        valid_publications.append({
            "Researcher": full_name,
            "Year": pub.get("publication_year"),
            "Type": pub.get("type", "N/A"),
            "Title": title,
            "Abstract": abstract,
            "Source": source,
            "Authors": ", ".join([auth["author"]["display_name"] for auth in pub.get("authorships", [])]),
            "Database Affiliation": researcher_affiliation,
            "Publication Institutions": publication_institutions,
            "Matched Affiliation": matched_affiliation,
            "Topic": topics,
            "Review Flag": review_flag,
        })

    print(f"Returning {len(valid_publications)} valid publications for {full_name}")
    return valid_publications



# Process a subset of researchers
def process_all(input_file, output_file):
    """Process all researchers and save results to a CSV file."""
    researchers = load_researcher_data(input_file)
    all_publications = []

    for _, row in researchers.iterrows():
        researcher_publications = process_researcher(row)
        all_publications.extend(researcher_publications)

    # Save results to CSV
    if all_publications:
        pd.DataFrame(all_publications).to_csv(output_file, index=False)
        print(f"Saved results to {output_file}")
    else:
        print("No publications to save.")


# Main function to run the subset pipeline
if __name__ == "__main__":
    input_file = "Data_clean/01_participants_with_geo.csv"  # Path to your input file
    output_file = "ViCom_Publications_Full.csv"  # Path to save results
    process_all(input_file, output_file)
# Out:
# Processing researcher: Federica Amici with affiliation: University of Leipzig
# Selected match: Federica Amici with ID: https://openalex.org/A5005613346
# Returning 50 valid publications for Federica Amici
# Processing researcher: Carly A. Anderson with affiliation: University College London
# Selected match: Carly A. Anderson with ID: https://openalex.org/A5000467902
# Returning 7 valid publications for Carly A. Anderson
# Processing researcher: Mailin Ines Antomo with affiliation: University of Göttingen
# No matches found for Mailin Ines Antomo, trying Mailin Antomo
# Selected match: Mailin Antomo with ID: https://openalex.org/A5084666745
# Returning 8 valid publications for Mailin Ines Antomo
# Processing researcher: Nadine Bade with affiliation: University of Potsdam
# Selected match: Nadine Bade with ID: https://openalex.org/A5008433566
# Returning 32 valid publications for Nadine Bade
# Processing researcher: Kathryn Barnes with affiliation: Goethe University Frankfurt
# Selected match: Kathryn Barnes-Burroughs with ID: https://openalex.org/A5047215176
# No publications found for Kathryn Barnes
# Processing researcher: Camila Antonio Barros with affiliation: Free University of Berlin
# Selected match: Camila Antônio Barros with ID: https://openalex.org/A5011779414
# Returning 7 valid publications for Camila Antonio Barros
# Processing researcher: Anastasia Bauer with affiliation: University of Cologne
# Selected match: Anastasia Bauer with ID: https://openalex.org/A5000645677
# Returning 11 valid publications for Anastasia Bauer
# Processing researcher: Reetu Bhattacharjee with affiliation: University of Münster
# Selected match: Reetu Bhattacharjee with ID: https://openalex.org/A5032972727
# Returning 15 valid publications for Reetu Bhattacharjee
# Processing researcher: Marion Bonnet with affiliation: University of Göttingen
# Selected match: Marion Bonnet with ID: https://openalex.org/A5102880428
# Returning 17 valid publications for Marion Bonnet
# Processing researcher: Jana Bressem with affiliation: TU Chemnitz
# Selected match: Jana Bressem with ID: https://openalex.org/A5089595222
# Returning 19 valid publications for Jana Bressem
# Processing researcher: Ingmar Brilmayer with affiliation: University of Cologne
# Selected match: Ingmar Brilmayer with ID: https://openalex.org/A5069144164
# Returning 10 valid publications for Ingmar Brilmayer
# Processing researcher: Yuqiu Chen with affiliation: University of Göttingen
# Selected match: Yuqiu Chen with ID: https://openalex.org/A5012512653
# Returning 50 valid publications for Yuqiu Chen
# Processing researcher: Valentina Colasanti with affiliation: Trinity College Dublin
# Selected match: Valentina Colasanti with ID: https://openalex.org/A5003159436
# Returning 6 valid publications for Valentina Colasanti
# Processing researcher: Aleksandra Ćwiek with affiliation: Leibniz-Zentrum Allgemeine Sprachwissenschaft Berlin
# Selected match: Aleksandra Ćwiek with ID: https://openalex.org/A5034843299
# Returning 20 valid publications for Aleksandra Ćwiek
# Processing researcher: Christian Dobel with affiliation: Jena University Hospital
# Selected match: Christian Dobel with ID: https://openalex.org/A5063765080
# Returning 50 valid publications for Christian Dobel
# Processing researcher: Cornelia Ebert with affiliation: Goethe University Frankfurt
# Selected match: Cornelia Ebert with ID: https://openalex.org/A5041382888
# Returning 17 valid publications for Cornelia Ebert
# Processing researcher: Natalia Filatkina with affiliation: University of Hamburg
# Selected match: Natalia Filatkina with ID: https://openalex.org/A5028398873
# Returning 30 valid publications for Natalia Filatkina
# Processing researcher: Thomas Finkbeiner with affiliation: University of Göttingen
# Selected match: Thomas Finkbeiner with ID: https://openalex.org/A5061306034
# Returning 50 valid publications for Thomas Finkbeiner
# Processing researcher: Lea Fricke with affiliation: University of Bochum
# Selected match: Lea Fricke with ID: https://openalex.org/A5070585922
# Returning 9 valid publications for Lea Fricke
# Processing researcher: Susanne Fuchs with affiliation: Leibniz-Zentrum Allgemeine Sprachwissenschaft Berlin
# Selected match: Susanne Fuchs with ID: https://openalex.org/A5001954776
# Returning 50 valid publications for Susanne Fuchs
# Processing researcher: Volker Gast with affiliation: University of Jena
# Selected match: Volker Gast with ID: https://openalex.org/A5049260281
# Returning 50 valid publications for Volker Gast
# Processing researcher: Pia Gehlbach with affiliation: University of Göttingen
# Selected match: Pia Gehlbach with ID: https://openalex.org/A5115442473
# Returning 1 valid publications for Pia Gehlbach
# Processing researcher: Susan Goldin-Meadow with affiliation: University of Chicago
# Selected match: Susan Goldin‐Meadow with ID: https://openalex.org/A5054951151
# Returning 50 valid publications for Susan Goldin-Meadow
# Processing researcher: Alina Gregori with affiliation: Goethe University Frankfurt
# Selected match: Alina Gregori with ID: https://openalex.org/A5088757066
# Returning 2 valid publications for Alina Gregori
# Processing researcher: Patrick Georg Grosz with affiliation: University of Oslo
# Selected match: Patrick Georg Grosz with ID: https://openalex.org/A5051287411
# Returning 15 valid publications for Patrick Georg Grosz
# Processing researcher: Jonas Hartke with affiliation: University of Göttingen
# No matches found for Jonas Hartke, trying Jonas Hartke
# No matches found for Jonas Hartke
# Processing researcher: Alexander Henlein with affiliation: Goethe University Frankfurt
# Selected match: Alexander Henlein with ID: https://openalex.org/A5048334698
# Returning 23 valid publications for Alexander Henlein
# Processing researcher: Oliver Herbort with affiliation: University of Würzburg
# Selected match: Oliver Herbort with ID: https://openalex.org/A5015368716
# Returning 27 valid publications for Oliver Herbort
# Processing researcher: Annika Herrmann with affiliation: University of Hamburg
# Selected match: Annika Herrmann with ID: https://openalex.org/A5109218392
# Returning 6 valid publications for Annika Herrmann
# Processing researcher: Stefan Hinterwimmer with affiliation: University of Hamburg
# Selected match: Stefan Hinterwimmer with ID: https://openalex.org/A5068928192
# Returning 43 valid publications for Stefan Hinterwimmer
# Processing researcher: Šárka Kadavá with affiliation: Leibniz-Zentrum Allgemeine Sprachwissenschaft Berlin
# Selected match: Šárka Kadavá with ID: https://openalex.org/A5032498230
# Returning 2 valid publications for Šárka Kadavá
# Processing researcher: Sotaro Kita with affiliation: University of Warwick
# Selected match: Sotaro Kita with ID: https://openalex.org/A5054897487
# Returning 38 valid publications for Sotaro Kita
# Processing researcher: Marianthi Koraka with affiliation: University of Göttingen
# Selected match: Marianthi Koraka with ID: https://openalex.org/A5044141952
# Returning 1 valid publications for Marianthi Koraka
# Processing researcher: Lisa-Marie Krause with affiliation: University of Würzburg
# Selected match: Lisa-Marie Krause with ID: https://openalex.org/A5028212747
# Returning 5 valid publications for Lisa-Marie Krause
# Processing researcher: Anna Kuder with affiliation: University of Cologne
# Selected match: Anna Kuder with ID: https://openalex.org/A5046681600
# Returning 5 valid publications for Anna Kuder
# Processing researcher: Frank Kügler with affiliation: Goethe University Frankfurt
# Selected match: Frank Kügler with ID: https://openalex.org/A5022219391
# Returning 21 valid publications for Frank Kügler
# Processing researcher: Silva Ladewig with affiliation: University of Göttingen
# Selected match: Silva H. Ladewig with ID: https://openalex.org/A5066844292
# Returning 19 valid publications for Silva Ladewig
# Processing researcher: Jens Lemanski with affiliation: University of Münster
# Selected match: Jens Lemanski with ID: https://openalex.org/A5018454984
# Returning 50 valid publications for Jens Lemanski
# Processing researcher: Katja Liebal with affiliation: University of Leipzig
# Selected match: Katja Liebal with ID: https://openalex.org/A5029820319
# Returning 50 valid publications for Katja Liebal
# Processing researcher: Rui Liu with affiliation: Ghent University
# Selected match: Rui Liu with ID: https://openalex.org/A5100448332
# Returning 50 valid publications for Rui Liu
# Processing researcher: Cornelia Loos with affiliation: University of Hamburg
# Selected match: Cornelia Loos with ID: https://openalex.org/A5030790559
# Returning 3 valid publications for Cornelia Loos
# Processing researcher: Andy Lücking with affiliation: Goethe University Frankfurt
# Selected match: Andy Lücking with ID: https://openalex.org/A5072493928
# Returning 50 valid publications for Andy Lücking
# Processing researcher: Carina Lüke with affiliation: University of Würzburg
# Selected match: Carina Lüke with ID: https://openalex.org/A5082989427
# Returning 27 valid publications for Carina Lüke
# Processing researcher: Vinicius Macuch with affiliation: University of Münster
# Selected match: Vinicius Macuch Silva with ID: https://openalex.org/A5071923351
# Returning 14 valid publications for Vinicius Macuch
# Processing researcher: Matteo Maran with affiliation: Donders Center for Cognition, Radboud University Nijmegen
# Selected match: Matteo Maran with ID: https://openalex.org/A5004457963
# Returning 18 valid publications for Matteo Maran
# Processing researcher: Alexander Mehler with affiliation: Goethe University Frankfurt
# Selected match: Alexander Mehler with ID: https://openalex.org/A5008340710
# Returning 50 valid publications for Alexander Mehler
# Processing researcher: Nina-Kristin Meister with affiliation: University of Göttingen
# Selected match: Nina-Kristin Meister with ID: https://openalex.org/A5092587588
# Returning 4 valid publications for Nina-Kristin Meister
# Processing researcher: Josiah Nii Ashie Neequaye with affiliation: University of Göttingen
# No matches found for Josiah Nii Ashie Neequaye, trying Josiah Neequaye
# No matches found for Josiah Nii Ashie Neequaye
# Processing researcher: Linda Oña with affiliation: MPI for Human Development Berlin
# Selected match: Linda Oña with ID: https://openalex.org/A5011153838
# Returning 22 valid publications for Linda Oña
# Processing researcher: Babajide Owoyele with affiliation: Erasmus School of Social and Behavioural Sciences, Rotterdam, The Netherlands & Hasso Plattner Institute, Potsdam
# Selected match: Babajide Owoyele with ID: https://openalex.org/A5002816775
# Returning 19 valid publications for Babajide Owoyele
# Processing researcher: Liona Paulus with affiliation: University of Hamburg
# Selected match: Liona Paulus with ID: https://openalex.org/A5070775531
# Returning 2 valid publications for Liona Paulus
# Processing researcher: Pamela Perniss with affiliation: University of Cologne
# Selected match: Pamela Perniss with ID: https://openalex.org/A5063715716
# Returning 21 valid publications for Pamela Perniss
# Processing researcher: Magnus Poppe with affiliation: Goethe University Frankfurt
# Selected match: Magnus Poppe Wang with ID: https://openalex.org/A5090889178
# Returning 1 valid publications for Magnus Poppe
# Processing researcher: Wim Pouw with affiliation: Donders Institute & MPI for Psycholinguistics Nijmegen
# Selected match: Wim Pouw with ID: https://openalex.org/A5051882032
# Returning 50 valid publications for Wim Pouw
# Processing researcher: Pilar Prieto with affiliation: Universitat Pompeu Fabra (UPF), Barcelona
# Selected match: Pilar Prieto with ID: https://openalex.org/A5062303366
# Returning 33 valid publications for Pilar Prieto
# Processing researcher: Pilar Prieto with affiliation: Universitat Pompeu Fabra (UPF), Barcelona
# Selected match: Pilar Prieto with ID: https://openalex.org/A5062303366
# Returning 33 valid publications for Pilar Prieto
# Processing researcher: Paula G. Sánchez Ramón with affiliation: Universitat Pompeu Fabra (UPF), Barcelona
# Selected match: Paula G. Sánchez-Ramón with ID: https://openalex.org/A5092438645
# Returning 3 valid publications for Paula G. Sánchez Ramón
# Processing researcher: Paula G. Sánchez Ramón with affiliation: Universitat Pompeu Fabra (UPF), Barcelona
# Selected match: Paula G. Sánchez-Ramón with ID: https://openalex.org/A5092438645
# Returning 3 valid publications for Paula G. Sánchez Ramón
# Processing researcher: Andrea Reichenberger with affiliation: University of Siegen
# Selected match: Andrea Reichenberger with ID: https://openalex.org/A5050849518
# Returning 27 valid publications for Andrea Reichenberger
# Processing researcher: Simone Schäffner with affiliation: University of Würzburg
# Selected match: Simone Schäffner with ID: https://openalex.org/A5020811300
# No publications found for Simone Schäffner
# Processing researcher: Tatjana Scheffler with affiliation: University of Bochum
# Selected match: Tatjana Scheffler with ID: https://openalex.org/A5026766545
# Returning 35 valid publications for Tatjana Scheffler
# Processing researcher: Philippe Schlenker with affiliation: CNRS (Institut Jean-Nicod, Paris) & New York University
# Selected match: Philippe Schlenker with ID: https://openalex.org/A5088255049
# Returning 49 valid publications for Philippe Schlenker
# Processing researcher: Marc Schulder with affiliation: University of Hamburg
# Selected match: Marc Schulder with ID: https://openalex.org/A5036949565
# Returning 29 valid publications for Marc Schulder
# Processing researcher: Martin Schulte-Rüther with affiliation: Heidelberg University Hospital
# Selected match: Martin Schulte‐Rüther with ID: https://openalex.org/A5039554973
# Returning 39 valid publications for Martin Schulte-Rüther
# Processing researcher: Petra Schumacher with affiliation: University of Cologne
# Selected match: Petra B. Schumacher with ID: https://openalex.org/A5042277242
# Returning 50 valid publications for Petra Schumacher
# Processing researcher: Sarah Schwarzenberg with affiliation: University of Hamburg
# Selected match: Sarah Jane Schwarzenberg with ID: https://openalex.org/A5002446565
# Returning 50 valid publications for Sarah Schwarzenberg
# Processing researcher: Stefan R. Schweinberger with affiliation: University of Jena
# Selected match: Stefan R. Schweinberger with ID: https://openalex.org/A5044655740
# Returning 48 valid publications for Stefan R. Schweinberger
# Processing researcher: Door Spruijt with affiliation: University of Cologne
# Selected match: Door Spruijt with ID: https://openalex.org/A5094213298
# Returning 1 valid publications for Door Spruijt
# Processing researcher: Markus Steinbach with affiliation: University of Göttingen
# Selected match: Markus Steinbach with ID: https://openalex.org/A5003115000
# Returning 40 valid publications for Markus Steinbach
# Processing researcher: Patrick Trettenbrein with affiliation: MPI for Human Cognitive & Brain Sciences Leipzig
# Selected match: Patrick C. Trettenbrein with ID: https://openalex.org/A5063925041
# Returning 30 valid publications for Patrick Trettenbrein
# Processing researcher: Vanessa Wing Yan Tsang with affiliation: University of Göttingen
# No matches found for Vanessa Wing Yan Tsang, trying Vanessa Tsang
# Selected match: Vanessa Tsang with ID: https://openalex.org/A5012310636
# Returning 1 valid publications for Vanessa Wing Yan Tsang
# Processing researcher: Celina Isabelle von Eiff with affiliation: University of Jena
# No matches found for Celina Isabelle von Eiff, trying Celina Eiff
# Selected match: Celina I. von Eiff with ID: https://openalex.org/A5011211284
# Returning 9 valid publications for Celina Isabelle von Eiff
# Processing researcher: Sebastian Walter with affiliation: Goethe University Frankfurt
# Selected match: Sebastian Walter with ID: https://openalex.org/A5053213047
# Returning 6 valid publications for Sebastian Walter
# Processing researcher: Vera Wolfrum with affiliation: University of Würzburg
# Selected match: Vera Wolfrum with ID: https://openalex.org/A5092530290
# Returning 2 valid publications for Vera Wolfrum
# Processing researcher: Emiliano Zaccarella with affiliation: MPI for Human Cognitive & Brain Sciences Leipzig
# Selected match: Emiliano Zaccarella with ID: https://openalex.org/A5014082518
# Returning 50 valid publications for Emiliano Zaccarella
# Processing researcher: Chiara Zulberti with affiliation: University of Leipzig
# Selected match: Chiara Zulberti with ID: https://openalex.org/A5092021166
# Returning 4 valid publications for Chiara Zulberti
# Saved results to ViCom_Publications_Full.csv
